# %%
import pandas as pd

# Direct download from HuggingFace
url = "https://huggingface.co/datasets/eloukas/edgar-corpus/resolve/refs%2Fconvert%2Fparquet/year_1993/test/0000.parquet"
df = pd.read_parquet(url)

print(f"Loaded {len(df)} documents")
print(df.head())
# Out:
# Loaded 133 documents
#           filename     cik  year  \
# 0   42246_1993.txt   42246  1993
# 1   18675_1993.txt   18675  1993
# 2  106926_1993.txt  106926  1993
# 3   20171_1993.txt   20171  1993
# 4   73960_1993.txt   73960  1993
#
#                                            section_1 section_1A section_1B  \
# 0  ITEM 1. BUSINESS\nGENERAL\nMirage Resorts, Inc...
# 1  Item 1. BUSINESS.\nIntroduction\nGeneral. Cent...
# 2  ITEM 1: BUSINESS\nWhitney Holding Corporation ...
# 3  ITEM 1. BUSINESS\nGENERAL\nThe Chubb Corporati...
# 4  ITEM 1. BUSINESS\nThe Company\nOhio Edison Com...
#
#                                            section_2  \
# 0  ITEM 2. PROPERTIES\nThe Mirage and Treasure Is...
# 1  Item 2. PROPERTIES.\nExisting Facilities\nThe ...
# 2  ITEM 2: PROPERTIES\nThe Company owns no real e...
# 3  ITEM 2. PROPERTIES\nThe executive offices of t...
# 4  ITEM 2. PROPERTIES\nThe Companies' respective ...
#
#                                            section_3  \
# ...
